# %% [markdown]
# ## Install dependencies

# %% [markdown]
# ### Install python3.11

# %%
# !apt-get update
# !apt install python3.11
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,113 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,298 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,486 kB]
# ...

# %% [markdown]
# ### Install poetry

# %%
# !pip install poetry

# %% [markdown]
# ### Clone the repository

# %%
# !git clone https://github.com/WIMU-BKT/WIMU-Data-poisoning.git
# Out:
# Cloning into 'WIMU-Data-poisoning'...
# remote: Enumerating objects: 299, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 299 (delta 15), reused 51 (delta 15), pack-reused 232 (from 1)
# Receiving objects: 100% (299/299), 7.92 MiB | 15.97 MiB/s, done.
# Resolving deltas: 100% (105/105), done.

# %%
import os

os.chdir("/content/WIMU-Data-poisoning")

# %% [markdown]
# ###Create poetry venv and install dependencies

# %%
# !git checkout audioldm
# !poetry env use python3.11 && poetry install
# Out:
# Streaming output truncated to the last 5000 lines.
#   - Installing nvidia-nccl-cu12 (2.21.5): Downloading... 20%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing pillow (11.0.0): Installing...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 60%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Downloading... 100%
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 47%
#   - Installing nvidia-nccl-cu12 (2.21.5): Downloading... 20%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing pillow (11.0.0): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Downloading... 20%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing pillow (11.0.0): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 50%
#   - Installing nvidia-nccl-cu12 (2.21.5): Downloading... 20%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing pillow (11.0.0): Installing...
#   - Installing pillow (11.0.0)
# ...

# %% [markdown]
# ## Run experiments

# %%
# !poetry run bash -c 'export PYTHONPATH=$PYTHONPATH:/content/WIMU-Data-poisoning/wimudp/watermarking && python ./wimudp/watermarking/models/audio_gen/audioldm_model.py'

# %%
from google.colab import files

files.download('./output/generation/19_11_2024_18_36_17_dog barking loudly_0.wav')
