# %% [markdown]
# ## Install dependencies

# %% [markdown]
# ### Install python3.11

# %%
# %%capture
# !apt-get update
# !apt install python3.11

# %% [markdown]
# ### Install poetry

# %%
# %%capture
# !pip install poetry

# %% [markdown]
# ### Clone the repository

# %%
# !git clone https://github.com/WIMU-BKT/WIMU-Data-poisoning.git
# Out:
# Cloning into 'WIMU-Data-poisoning'...
# remote: Enumerating objects: 363, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 363 (delta 34), reused 95 (delta 24), pack-reused 232 (from 1)
# Receiving objects: 100% (363/363), 9.90 MiB | 26.97 MiB/s, done.
# Resolving deltas: 100% (124/124), done.

# %%
import os

os.chdir("/content/WIMU-Data-poisoning")

# %% [markdown]
# ###Create poetry venv and install dependencies

# %%
# !git checkout audioldm
# !poetry env use python3.11 && poetry install
# Out:
# Already on 'audioldm'
# Your branch is up to date with 'origin/audioldm'.
# Using virtualenv: /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11
# Installing dependencies from lock file
#
# Package operations: 72 installs, 0 updates, 0 removals
#
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Pending...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Pending...
#   - Installing wcwidth (0.2.13): Pending...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Pending...
#   - Installing wcwidth (0.2.13): Pending...
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Pending...
#   - Installing wcwidth (0.2.13): Pending...
#   - Installing wcwidth (0.2.13): Pending...
#   - Installing triton (3.1.0): Downloading... 0%
#   - Installing wcwidth (0.2.13): Pending...
#   - Installing wcwidth (0.2.13): Downloading... 0%
#   - Installing wcwidth (0.2.13): Downloading... 100%
#   - Installing wcwidth (0.2.13): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0): Pending...
#   - Installing websockets (12.0): Downloading... 0%
#   - Installing websockets (12.0): Downloading... 100%
#   - Installing websockets (12.0): Installing...
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1): Pending...
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 100%
#   - Installing yarl (1.17.1): Installing...
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Downloading... 0%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 2%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Downloading... 0%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 7%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 10%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Downloading... 10%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Downloading... 10%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Downloading... 10%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 4%
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cufft/__init__.py over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cufft/include/__init__.py over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cufft/include/cudalibxt.h over existing file
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Downloading... 10%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cufft/include/cufft.h over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cufft/include/cufftXt.h over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cufft/include/cufftw.h over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cufft/lib/__init__.py over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cufft/lib/libcufft.so.11 over existing file
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Downloading... 10%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Downloading... 10%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/__init__.py over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cusolver/__init__.py over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cusolver/include/__init__.py over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cusolver/include/cusolverDn.h over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cusolver/include/cusolverMg.h over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cusolver/include/cusolverRf.h over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cusolver/include/cusolverSp.h over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cusolver/include/cusolverSp_LOWLEVEL_PREVIEW.h over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cusolver/include/cusolver_common.h over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cusolver/lib/__init__.py over existing file
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/cusolver/lib/libcusolver.so.11 over existing file
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 18%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 20%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Downloading... 20%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 7%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Pending...
#   - Installing triton (3.1.0): Downloading... 20%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 20%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 20%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 28%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 30%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 30%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 10%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 30%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 38%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 40%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 40%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 12%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 40%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 48%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 48%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 15%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 48%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 50%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 51%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 51%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 16%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 51%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 59%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 59%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 18%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 59%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 59%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 20%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 59%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 66%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 70%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 70%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 22%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 70%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 77%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 77%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 24%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 77%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 80%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 80%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 26%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 80%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 87%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 90%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 90%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 28%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 90%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 90%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 90%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 90%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 30%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 90%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 90%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 90%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 99%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 99%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 32%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 99%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 100%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 100%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 37%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 100%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 100%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 40%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5): Installing...
#   - Installing triton (3.1.0): Downloading... 100%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Downloading... 100%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Downloading... 100%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Downloading... 100%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 47%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Downloading... 100%
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 50%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 58%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 60%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 69%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 78%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 80%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 85%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 90%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 95%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 100%
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing triton (3.1.0)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Installing...
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
# Installing /root/.cache/pypoetry/virtualenvs/wimudp-B6pDilnr-py3.11/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70)
#   - Installing nvidia-cufft-cu12 (11.0.2.54)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107)
#   - Installing nvidia-nccl-cu12 (2.21.5)
#   - Installing triton (3.1.0)
#   - Installing wcwidth (0.2.13)
#   - Installing websockets (12.0)
#   - Installing yarl (1.17.1)
#   - Installing aiofiles (24.1.0): Pending...
#   - Installing aiohttp (3.11.2): Pending...
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Pending...
#   - Installing fastapi (0.115.5): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing aiohttp (3.11.2): Pending...
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Pending...
#   - Installing fastapi (0.115.5): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing aiofiles (24.1.0): Downloading... 0%
#   - Installing aiohttp (3.11.2): Pending...
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Pending...
#   - Installing fastapi (0.115.5): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing aiohttp (3.11.2): Pending...
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Pending...
#   - Installing fastapi (0.115.5): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing aiofiles (24.1.0): Downloading... 100%
#   - Installing aiohttp (3.11.2): Pending...
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Pending...
#   - Installing fastapi (0.115.5): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing fastapi (0.115.5): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Downloading... 0%
#   - Installing fastapi (0.115.5): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing aiohttp (3.11.2): Pending...
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Downloading... 0%
#   - Installing fastapi (0.115.5): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing aiofiles (24.1.0): Installing...
#   - Installing aiohttp (3.11.2): Pending...
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Downloading... 0%
#   - Installing fastapi (0.115.5): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing fastapi (0.115.5): Downloading... 0%
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing fastapi (0.115.5): Downloading... 0%
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Downloading... 100%
#   - Installing fastapi (0.115.5): Downloading... 0%
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing fastapi (0.115.5): Downloading... 0%
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5): Downloading... 0%
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5): Downloading... 0%
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing aiohttp (3.11.2): Downloading... 0%
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5): Downloading... 0%
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing fastapi (0.115.5): Downloading... 100%
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing aiohttp (3.11.2): Downloading... 0%
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5): Downloading... 100%
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing aiofiles (24.1.0)
#   - Installing aiohttp (3.11.2): Downloading... 0%
#   - Installing altair (5.4.1): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5): Downloading... 100%
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing fastapi (0.115.5): Installing...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5): Installing...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing altair (5.4.1): Downloading... 0%
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5): Installing...
#   - Installing ffmpy (0.4.0): Pending...
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing ffmpy (0.4.0): Downloading... 0%
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing ffmpy (0.4.0): Downloading... 100%
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing ffmpy (0.4.0): Installing...
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing jupyter-core (5.7.2): Pending...
#   - Installing altair (5.4.1): Downloading... 0%
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing jupyter-core (5.7.2): Pending...
#   - Installing aiohttp (3.11.2): Downloading... 60%
#   - Installing altair (5.4.1): Downloading... 0%
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing jupyter-core (5.7.2): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing jupyter-core (5.7.2): Pending...
#   - Installing gradio-client (0.2.9): Downloading... 0%
#   - Installing jedi (0.19.2): Pending...
#   - Installing jupyter-core (5.7.2): Pending...
#   - Installing jupyter-core (5.7.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Downloading... 0%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Downloading... 0%
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Downloading... 0%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Downloading... 0%
#   - Installing altair (5.4.1): Downloading... 100%
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Downloading... 0%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Downloading... 100%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Downloading... 100%
#   - Installing gradio-client (0.2.9): Downloading... 100%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Downloading... 100%
#   - Installing jupyter-core (5.7.2): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Installing...
#   - Installing gradio-client (0.2.9): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Installing...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Installing...
#   - Installing altair (5.4.1): Installing...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Installing...
#   - Installing altair (5.4.1): Installing...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Installing...
#   - Installing aiohttp (3.11.2): Downloading... 100%
#   - Installing altair (5.4.1): Installing...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2): Installing...
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Pending...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Pending...
#   - Installing gradio-client (0.2.9)
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Pending...
#   - Installing matplotlib (3.7.0): Pending...
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Pending...
#   - Installing matplotlib (3.7.0): Pending...
#   - Installing jedi (0.19.2): Downloading... 50%
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Pending...
#   - Installing matplotlib (3.7.0): Pending...
#   - Installing altair (5.4.1): Installing...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9)
#   - Installing jedi (0.19.2): Downloading... 50%
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Pending...
#   - Installing matplotlib (3.7.0): Pending...
#   - Installing aiohttp (3.11.2): Installing...
#   - Installing altair (5.4.1): Installing...
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9)
#   - Installing jedi (0.19.2): Downloading... 50%
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Pending...
#   - Installing matplotlib (3.7.0): Pending...
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Pending...
#   - Installing matplotlib (3.7.0): Pending...
#   - Installing jedi (0.19.2): Downloading... 100%
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Pending...
#   - Installing matplotlib (3.7.0): Pending...
#   - Installing matplotlib (3.7.0): Pending...
#   - Installing librosa (0.9.2): Downloading... 0%
#   - Installing matplotlib (3.7.0): Pending...
#   - Installing matplotlib (3.7.0): Downloading... 0%
#   - Installing matplotlib (3.7.0): Downloading... 0%
#   - Installing librosa (0.9.2): Downloading... 100%
#   - Installing matplotlib (3.7.0): Downloading... 0%
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Downloading... 100%
#   - Installing matplotlib (3.7.0): Downloading... 0%
#   - Installing jedi (0.19.2): Installing...
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Downloading... 100%
#   - Installing matplotlib (3.7.0): Downloading... 0%
#   - Installing matplotlib (3.7.0): Downloading... 0%
#   - Installing librosa (0.9.2): Installing...
#   - Installing matplotlib (3.7.0): Downloading... 0%
#   - Installing matplotlib (3.7.0): Downloading... 10%
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9)
#   - Installing jedi (0.19.2): Installing...
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Installing...
#   - Installing matplotlib (3.7.0): Downloading... 10%
#   - Installing altair (5.4.1)
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9)
#   - Installing jedi (0.19.2): Installing...
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2): Installing...
#   - Installing matplotlib (3.7.0): Downloading... 10%
#   - Installing matplotlib-inline (0.1.7): Pending...
#   - Installing matplotlib (3.7.0): Downloading... 10%
#   - Installing matplotlib-inline (0.1.7): Pending...
#   - Installing librosa (0.9.2)
#   - Installing matplotlib (3.7.0): Downloading... 10%
#   - Installing matplotlib-inline (0.1.7): Pending...
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing matplotlib-inline (0.1.7): Downloading... 0%
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing matplotlib-inline (0.1.7): Downloading... 100%
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing matplotlib-inline (0.1.7): Installing...
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing matplotlib-inline (0.1.7): Installing...
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing matplotlib (3.7.0): Downloading... 20%
#   - Installing matplotlib-inline (0.1.7): Installing...
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing matplotlib-inline (0.1.7)
#   - Installing mdit-py-plugins (0.3.3): Pending...
#   - Installing orjson (3.10.11): Pending...
#   - Installing orjson (3.10.11): Downloading... 0%
#   - Installing orjson (3.10.11): Downloading... 100%
#   - Installing orjson (3.10.11): Installing...
#   - Installing orjson (3.10.11): Installing...
#   - Installing mdit-py-plugins (0.3.3): Downloading... 0%
#   - Installing orjson (3.10.11): Installing...
#   - Installing orjson (3.10.11)
#   - Installing pandas (2.2.3): Pending...
#   - Installing orjson (3.10.11)
#   - Installing pandas (2.2.3): Pending...
#   - Installing mdit-py-plugins (0.3.3): Downloading... 100%
#   - Installing orjson (3.10.11)
#   - Installing pandas (2.2.3): Pending...
#   - Installing orjson (3.10.11)
#   - Installing pandas (2.2.3): Pending...
#   - Installing mdit-py-plugins (0.3.3): Installing...
#   - Installing orjson (3.10.11)
#   - Installing pandas (2.2.3): Pending...
#   - Installing pandas (2.2.3): Downloading... 0%
#   - Installing altair (5.4.1)
#   - Installing antlr4-python3-runtime (4.9.3): Preparing...
#   - Installing fastapi (0.115.5)
#   - Installing ffmpy (0.4.0)
#   - Installing gradio-client (0.2.9)
#   - Installing jedi (0.19.2): Installing...
#   - Installing jupyter-core (5.7.2)
#   - Installing librosa (0.9.2)
#   - Installing matplotlib (3.7.0): Downloading... 20%
#   - Installing matplotlib-inline (0.1.7)
#   - Installing mdit-py-plugins (0.3.3): Installing...
#   - Installing orjson (3.10.11)
#   - Installing pandas (2.2.3): Downloading... 0%
#   - Installing aiohttp (3.11.2)
#   - Installing altair (5.4.1)
# ...
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121): Installing...
#   - Installing transformers (4.29.0): Installing...
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121): Installing...
#   - Installing transformers (4.29.0): Installing...
#   - Installing transformers (4.29.0): Installing...
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0): Installing...
#   - Installing jupyter-client (8.6.3)
#   - Installing mccabe (0.7.0)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nest-asyncio (1.6.0)
#   - Installing omegaconf (2.3.0)
#   - Installing pathspec (0.12.1)
#   - Installing progressbar (2.5): Preparing...
#   - Installing pycodestyle (2.12.1)
#   - Installing pyflakes (3.2.0)
#   - Installing tomlkit (0.13.2)
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0): Installing...
#   - Installing julius (0.2.7): Installing...
#   - Installing jupyter-client (8.6.3)
#   - Installing mccabe (0.7.0)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nest-asyncio (1.6.0)
#   - Installing omegaconf (2.3.0)
#   - Installing pathspec (0.12.1)
#   - Installing progressbar (2.5): Preparing...
#   - Installing pycodestyle (2.12.1)
#   - Installing pyflakes (3.2.0)
#   - Installing tomlkit (0.13.2)
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0): Installing...
#   - Installing jupyter-client (8.6.3)
#   - Installing mccabe (0.7.0)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nest-asyncio (1.6.0)
#   - Installing omegaconf (2.3.0)
#   - Installing pathspec (0.12.1)
#   - Installing progressbar (2.5): Preparing...
#   - Installing pycodestyle (2.12.1)
#   - Installing pyflakes (3.2.0)
#   - Installing tomlkit (0.13.2)
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0): Installing...
#   - Installing julius (0.2.7)
#   - Installing jupyter-client (8.6.3)
#   - Installing mccabe (0.7.0)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nest-asyncio (1.6.0)
#   - Installing omegaconf (2.3.0)
#   - Installing pathspec (0.12.1)
#   - Installing progressbar (2.5): Preparing...
#   - Installing pycodestyle (2.12.1)
#   - Installing pyflakes (3.2.0)
#   - Installing tomlkit (0.13.2)
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0): Installing...
#   - Installing pycodestyle (2.12.1)
#   - Installing pyflakes (3.2.0)
#   - Installing tomlkit (0.13.2)
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0): Installing...
#   - Installing progressbar (2.5): Installing...
#   - Installing pycodestyle (2.12.1)
#   - Installing pyflakes (3.2.0)
#   - Installing tomlkit (0.13.2)
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0): Installing...
#   - Installing pycodestyle (2.12.1)
#   - Installing pyflakes (3.2.0)
#   - Installing tomlkit (0.13.2)
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0): Installing...
#   - Installing progressbar (2.5)
#   - Installing pycodestyle (2.12.1)
#   - Installing pyflakes (3.2.0)
#   - Installing tomlkit (0.13.2)
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0): Installing...
#   - Installing transformers (4.29.0)
#   - Installing ipython (8.29.0)
#   - Installing isort (5.13.2)
#   - Installing julius (0.2.7)
#   - Installing jupyter-client (8.6.3)
#   - Installing mccabe (0.7.0)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nest-asyncio (1.6.0)
#   - Installing omegaconf (2.3.0)
#   - Installing pathspec (0.12.1)
#   - Installing progressbar (2.5)
#   - Installing pycodestyle (2.12.1)
#   - Installing pyflakes (3.2.0)
#   - Installing tomlkit (0.13.2)
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0)
#   - Installing gradio (3.36.1)
#   - Installing ipython (8.29.0)
#   - Installing isort (5.13.2)
#   - Installing julius (0.2.7)
#   - Installing jupyter-client (8.6.3)
#   - Installing mccabe (0.7.0)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nest-asyncio (1.6.0)
#   - Installing omegaconf (2.3.0)
#   - Installing pathspec (0.12.1)
#   - Installing progressbar (2.5)
#   - Installing pycodestyle (2.12.1)
#   - Installing pyflakes (3.2.0)
#   - Installing tomlkit (0.13.2)
#   - Installing torchaudio (2.5.1+cu121)
#   - Installing torchlibrosa (0.0.9)
#   - Installing torchvision (0.20.1+cu121)
#   - Installing transformers (4.29.0)
#   - Installing audioldm (0.1.1): Pending...
#   - Installing audioseal (0.1.4): Pending...
#   - Installing black (24.10.0): Pending...
#   - Installing flake8 (7.1.1): Pending...
#   - Installing ipykernel (6.29.5): Pending...
#   - Installing mypy (1.13.0): Pending...
#   - Installing mypy (1.13.0): Pending...
#   - Installing ipykernel (6.29.5): Downloading... 0%
#   - Installing mypy (1.13.0): Pending...
#   - Installing ipykernel (6.29.5): Downloading... 0%
#   - Installing mypy (1.13.0): Pending...
#   - Installing flake8 (7.1.1): Downloading... 0%
#   - Installing ipykernel (6.29.5): Downloading... 0%
#   - Installing mypy (1.13.0): Pending...
#   - Installing flake8 (7.1.1): Downloading... 0%
#   - Installing ipykernel (6.29.5): Downloading... 0%
#   - Installing mypy (1.13.0): Pending...
#   - Installing black (24.10.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Downloading... 0%
#   - Installing ipykernel (6.29.5): Downloading... 0%
#   - Installing mypy (1.13.0): Pending...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing ipykernel (6.29.5): Downloading... 100%
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing ipykernel (6.29.5): Downloading... 100%
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Downloading... 100%
#   - Installing ipykernel (6.29.5): Downloading... 100%
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing black (24.10.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing audioseal (0.1.4): Downloading... 0%
#   - Installing black (24.10.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing black (24.10.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing audioseal (0.1.4): Downloading... 100%
#   - Installing black (24.10.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing black (24.10.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing audioseal (0.1.4): Installing...
#   - Installing black (24.10.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing audioseal (0.1.4): Installing...
#   - Installing black (24.10.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing audioldm (0.1.1): Downloading... 0%
#   - Installing audioseal (0.1.4): Installing...
#   - Installing black (24.10.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing black (24.10.0): Downloading... 70%
#   - Installing flake8 (7.1.1): Installing...
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing peft (0.13.2): Pending...
#   - Installing black (24.10.0): Downloading... 70%
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing peft (0.13.2): Pending...
#   - Installing audioseal (0.1.4)
#   - Installing black (24.10.0): Downloading... 70%
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5): Installing...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing peft (0.13.2): Pending...
#   - Installing pylint (3.3.1): Pending...
#   - Installing pylint (3.3.1): Pending...
#   - Installing peft (0.13.2): Downloading... 0%
#   - Installing pylint (3.3.1): Pending...
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing peft (0.13.2): Downloading... 0%
#   - Installing pylint (3.3.1): Pending...
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 0%
#   - Installing peft (0.13.2): Downloading... 0%
#   - Installing pylint (3.3.1): Pending...
#   - Installing peft (0.13.2): Downloading... 0%
#   - Installing pylint (3.3.1): Pending...
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Downloading... 0%
#   - Installing pylint (3.3.1): Pending...
#   - Installing pylint (3.3.1): Downloading... 0%
#   - Installing pylint (3.3.1): Downloading... 0%
#   - Installing peft (0.13.2): Downloading... 100%
#   - Installing pylint (3.3.1): Downloading... 0%
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Downloading... 100%
#   - Installing pylint (3.3.1): Downloading... 0%
#   - Installing black (24.10.0): Downloading... 100%
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Downloading... 100%
#   - Installing pylint (3.3.1): Downloading... 0%
#   - Installing pylint (3.3.1): Downloading... 0%
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Downloading... 0%
#   - Installing pylint (3.3.1): Downloading... 100%
#   - Installing audioseal (0.1.4)
#   - Installing black (24.10.0): Downloading... 100%
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Downloading... 100%
#   - Installing audioldm (0.1.1): Downloading... 90%
#   - Installing audioseal (0.1.4)
#   - Installing black (24.10.0): Downloading... 100%
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Downloading... 100%
#   - Installing pylint (3.3.1): Installing...
#   - Installing audioseal (0.1.4)
#   - Installing black (24.10.0): Downloading... 100%
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Installing...
#   - Installing audioldm (0.1.1): Downloading... 100%
#   - Installing audioseal (0.1.4)
#   - Installing black (24.10.0): Downloading... 100%
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Installing...
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Installing...
#   - Installing black (24.10.0): Installing...
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Installing...
#   - Installing audioseal (0.1.4)
#   - Installing black (24.10.0): Installing...
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Installing...
#   - Installing audioldm (0.1.1): Installing...
#   - Installing audioseal (0.1.4)
#   - Installing black (24.10.0): Installing...
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 10%
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Installing...
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Installing...
#   - Installing mypy (1.13.0): Downloading... 30%
#   - Installing peft (0.13.2): Installing...
#   - Installing pylint (3.3.1): Installing...
#   - Installing pylint (3.3.1): Installing...
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1): Installing...
#   - Installing audioseal (0.1.4)
#   - Installing black (24.10.0): Installing...
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 30%
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1): Installing...
#   - Installing audioldm (0.1.1)
#   - Installing audioseal (0.1.4)
#   - Installing black (24.10.0): Installing...
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 30%
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1): Installing...
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1): Installing...
#   - Installing mypy (1.13.0): Downloading... 40%
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1): Installing...
#   - Installing pylint (3.3.1)
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 40%
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1)
#   - Installing black (24.10.0)
#   - Installing flake8 (7.1.1)
#   - Installing ipykernel (6.29.5)
#   - Installing mypy (1.13.0): Downloading... 40%
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1)
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1)
#   - Installing mypy (1.13.0): Downloading... 80%
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1)
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1)
#   - Installing mypy (1.13.0): Downloading... 100%
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1)
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1)
#   - Installing mypy (1.13.0): Installing...
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1)
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1)
#   - Installing mypy (1.13.0)
#   - Installing peft (0.13.2)
#   - Installing pylint (3.3.1)
#
# Installing the current project: wimudp (0.1.0)Installing the current project: wimudp (0.1.0)

# %% [markdown]
# ## Run experiments

# %%
# %%bash
# poetry run bash -c \
# 'export PYTHONPATH=$PYTHONPATH:/content/WIMU-Data-poisoning/wimudp/watermarking \
# && python ./wimudp/watermarking/run.py -m audioldm -a brahms'
# Out:
# Process is terminated.
